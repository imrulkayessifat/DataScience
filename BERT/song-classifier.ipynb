# %%
import glob
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
#!pip install ktrain
#!pip install git+https://github.com/amaiya/eli5@tfkeras_0_10_1


import ktrain
from ktrain import text
import numpy as np
import glob
import pandas as pd

# %%
all_file= glob.glob("./songData/*.xlsx")
len(all_file)
# Out:
# 21

# %% [markdown]
# # Preprocessing steps

# %%
names = []
count = []
clusters = []
data = []

for each in all_file:
    temp = pd.read_excel(each)
    
    
    count.append(len(temp))
    names.append(each.split('/')[1][:-5])
    clusters.append(temp['songType'].iloc[0])
    
    
    data.append(temp)
    
cluster_ids =clusters

# %%
temp

# %%
data = pd.concat(data)
data = data.sample(frac = 1)

data

# %%
stopwords = [ 'হাই', 'ফ্রিকুয়েন্সি', 'কিন্তু', 'অপ্রয়োজনীয়', 'শব্দ' ]

# %%
data['lyrics'] = data['lyrics'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# %%
X_train, X_test, y_train, y_test =  train_test_split(data['lyrics'], data['songType'], test_size=0.30, random_state=42, stratify=data['songType'] )

# %% [markdown]
# # New Section

# %%
y_train = [str(x) for x in y_train]
y_test = [str(x) for x in y_test]

MODEL_NAME = 'neuralspace-reverie/indic-transformers-bn-distilbert'
t = text.Transformer(MODEL_NAME, maxlen=500)

trn = t.preprocess_train(list(X_train), y_train)
val = t.preprocess_test(list(X_test), y_test)

# %%
model = t.get_classifier()

# %%
learner = ktrain.get_learner(model, train_data=trn, val_data=val, batch_size=8)

# %%
learner.fit_onecycle(1e-5, 10)
# Out:
# begin training using onecycle policy with max lr of 1e-05...
# Epoch 1/10
# 360/360 [==============================] - 266s 711ms/step - loss: 2.5683 - accuracy: 0.2931 - val_loss: 2.0916 - val_accuracy: 0.3937
# Epoch 2/10
# 360/360 [==============================] - 256s 709ms/step - loss: 1.8406 - accuracy: 0.4236 - val_loss: 1.6195 - val_accuracy: 0.4513
# Epoch 3/10
# 360/360 [==============================] - 256s 709ms/step - loss: 1.5294 - accuracy: 0.5026 - val_loss: 1.4389 - val_accuracy: 0.5049
# Epoch 4/10
# 360/360 [==============================] - 256s 710ms/step - loss: 1.3110 - accuracy: 0.5747 - val_loss: 1.3655 - val_accuracy: 0.5381
# Epoch 5/10
# 360/360 [==============================] - 256s 710ms/step - loss: 1.1004 - accuracy: 0.6544 - val_loss: 1.3399 - val_accuracy: 0.5511
# Epoch 6/10
# 360/360 [==============================] - 256s 710ms/step - loss: 0.8789 - accuracy: 0.7285 - val_loss: 1.3619 - val_accuracy: 0.5690
# Epoch 7/10
# 360/360 [==============================] - 256s 711ms/step - loss: 0.6433 - accuracy: 0.8183 - val_loss: 1.3906 - val_accuracy: 0.5763
# Epoch 8/10
# 360/360 [==============================] - 256s 711ms/step - loss: 0.4683 - accuracy: 0.8834 - val_loss: 1.4893 - val_accuracy: 0.5779
# Epoch 9/10
# 360/360 [==============================] - 257s 711ms/step - loss: 0.3740 - accuracy: 0.9123 - val_loss: 1.5475 - val_accuracy: 0.5698
# Epoch 10/10
# 360/360 [==============================] - 257s 711ms/step - loss: 0.3270 - accuracy: 0.9276 - val_loss: 1.5525 - val_accuracy: 0.5698

# %%
valid = learner.validate(class_names=t.get_classes())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.47      0.60      0.53       308
#           10       0.00      0.00      0.00        13
#           11       0.38      0.16      0.22        19
#           12       0.10      0.05      0.07        38
#           13       0.57      0.56      0.57       213
#           14       0.36      0.24      0.29        17
#           15       0.00      0.00      0.00         1
#           16       0.00      0.00      0.00         2
#           17       0.86      0.91      0.89       234
#           18       0.00      0.00      0.00         3
#           19       0.60      0.43      0.50        14
#            2       0.00      0.00      0.00         4
#           20       0.00      0.00      0.00         3
#            3       0.49      0.49      0.49       229
#            4       0.00      0.00      0.00         2
#            5       0.00      0.00      0.00        17
#            6       0.56      0.64      0.60        28
#            7       0.64      0.56      0.60        62
#            8       0.00      0.00      0.00         6
#            9       1.00      0.06      0.11        17
#
#     accuracy                           0.57      1232
#    macro avg       0.29      0.22      0.23      1232
# weighted avg       0.55      0.57      0.55      1232
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
